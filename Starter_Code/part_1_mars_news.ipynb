# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com/'
browser.visit(url)
#browser.is_element_present_by_css('button#more', wait_time=1)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
html = browser.html
news_soup = soup(html, 'html.parser')
#slide_elem = news_soup('div.list_text')

# %%
# mars_title_preview = []
# info = news_soup.find_all('div.list_text')
# for x in info:
#     title = info.find_all('div', class_='content_title')
#     preview = info.find_all('div', 'article_teaser_body')
#     mars_title_preview[title] = preview
#     if title not in mars_title_preview:
#             mars_title_preview.append(title)
#     if preview not in mars_title_preview:
#             mars_title_preview.append(preview)

# %%
# mars_title_preview
# Out:
# []

# %%
# Extract all the text elements
news_soup
# Out:
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet" type="text/css"/>
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
# <title>News - Mars Exploration Program</title>
# </head>
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# ...

# %%
# article_titles = []
# for title in news_soup.find_all('div', class_='content_title'):
#         titles = title.get_text()
#         if titles not in article_titles:
#             article_titles.append(titles)

# %%
# article_titles

# %%
# article_previews = []
# for preview in news_soup.find_all('div', class_='article_teaser_body'):
#         previews = preview.get_text()
#         if previews not in article_previews:
#             article_previews.append(previews)

# %%
# article_previews

# %%
# mars = []
# for index in range(0, len(article_previews)):
#     mars_articles = {'title': article_titles[index],'preview': article_previews[index]}
#     mars.append(mars_articles)
    
# mars

# %%
# #def mars_articles(article_titles, article_previews):
# mars_articles = dict(zip(article_titles, article_previews))

# #print(mars_articles(article_titles, article_previews))

# %%
# print(mars_articles)

# %%
# # Extract all the text elements
# for preview in news_soup.find_all('div', class_='article_teaser_body'):
#         print(preview.get_text())

# %%
# def mars_title_preview(titles, previews):
#     mars_title_preview = {}
#     for title in news_soup.find_all('div', class_='content_title'):
#             titles = title.get_text()
#             if titles not in mars_title_preview:
#                 mars_title_preview.update(titles)
#             for preview in news_soup.find_all('div', class_='article_teaser_body'):
#                 previews = preview.get_text()
#                 if previews not in mars_title_preview:
#                     mars_title_preview.update(previews)
#     return mars_title_preview

# %%
# print(mars_title_preview)

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries

# %%
article_titles = []
for title in news_soup.find_all('div', class_='content_title'):
        titles = title.get_text()
        if titles not in article_titles:
            article_titles.append(titles)

# %%
article_titles
# Out:
# ['NASA Wins Two Emmy Awards for Interactive Mission Coverage',
#  "NASA's Perseverance Rover Mission Getting in Shape for Launch",
#  "NASA's Mars 2020 Rover Closer to Getting Its Name",
#  "Robotic Toolkit Added to NASA's Mars 2020 Rover",
#  "NASA's Perseverance Rover 100 Days Out",
#  "Nine Finalists Chosen in NASA's Mars 2020 Rover Naming Contest",
#  "Alabama High School Student Names NASA's Mars Helicopter",
#  'NASA Mars Mission Connects With Bosnian and Herzegovinian Town',
#  "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#  "NASA's InSight Flexes Its Arm While Its 'Mole' Hits Pause",
#  "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus",
#  'Independent Review Indicates NASA Prepared for Mars Sample Return Campaign',
#  'NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet',
#  "NASA's Perseverance Rover Will Peer Beneath Mars' Surface ",
#  "From JPL's Mailroom to Mars and Beyond"]

# %%
article_previews = []
for preview in news_soup.find_all('div', class_='article_teaser_body'):
        previews = preview.get_text()
        if previews not in article_previews:
            article_previews.append(previews)

# %%
article_previews
# Out:
# ["NASA-JPL's coverage of the Mars InSight landing earns one of the two wins, making this the NASA center's second Emmy.",
#  'Stacking spacecraft components on top of each other is one of the final assembly steps before a mission launches to the Red Planet. ',
#  "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.",
#  "The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. ",
#  "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.",
#  "Nine finalists have been chosen in the essay contest for K-12 students across U.S. to name NASA's next Mars rover. Now you can help by voting for your favorite. ",
# ...

# %%
# Loop through the text elements
# Extract the title and preview text from the elements
# Store each title and preview pair in a dictionary
# Add the dictionary to the list
mars = []
for index in range(0, len(article_previews)):
    mars_articles = {'title': article_titles[index],'preview': article_previews[index]}
    mars.append(mars_articles) = []
for index in range(0, len(article_previews)):
    mars_articles = {'title': article_titles[index],'preview': article_previews[index]}
    mars.append(mars_articles)

# %%
mars
# Out:
# [{'title': 'NASA Wins Two Emmy Awards for Interactive Mission Coverage',
#   'preview': "NASA-JPL's coverage of the Mars InSight landing earns one of the two wins, making this the NASA center's second Emmy."},
#  {'title': "NASA's Perseverance Rover Mission Getting in Shape for Launch",
#   'preview': 'Stacking spacecraft components on top of each other is one of the final assembly steps before a mission launches to the Red Planet. '},
#  {'title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'preview': "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July."},
#  {'title': "Robotic Toolkit Added to NASA's Mars 2020 Rover",
#   'preview': "The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. "},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
# ...

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
import json
json_mars = json.dumps(mars)

# %%
print(json_mars)
# Out:
# [{"title": "NASA Wins Two Emmy Awards for Interactive Mission Coverage", "preview": "NASA-JPL's coverage of the Mars InSight landing earns one of the two wins, making this the NASA center's second Emmy."}, {"title": "NASA's Perseverance Rover Mission Getting in Shape for Launch", "preview": "Stacking spacecraft components on top of each other is one of the final assembly steps before a mission launches to the Red Planet. "}, {"title": "NASA's Mars 2020 Rover Closer to Getting Its Name", "preview": "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July."}, {"title": "Robotic Toolkit Added to NASA's Mars 2020 Rover", "preview": "The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. "}, {"title": "NASA's Perseverance Rover 100 Days Out", "preview": "Mark your calendars: The agency's latest rover has only about 8,6
# ...

# %%
jsonFile = open("mars_data.json", "w")
jsonFile.write(json_mars)
jsonFile.close()

# %%
# Export data to MongoDB
